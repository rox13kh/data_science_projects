# %%
import datetime as dt
import matplotlib.pyplot as plt 
from matplotlib import style
import numpy as np
import pandas as pd
import pandas_datareader.data as web

# %%
df['Volume']
# Out:
# Symbols             FB      GOOGL         MSFT
# Date
# 2017-01-03  20663900.0  1959000.0   20694100.0
# 2017-01-04  19630900.0  1515300.0   21340000.0
# 2017-01-05  19492200.0  1340500.0   24876000.0
# 2017-01-06  28545300.0  2017100.0   19922900.0
# 2017-01-09  22880400.0  1406800.0   20256600.0
# 2017-01-10  17324600.0  1197400.0   18593000.0
# 2017-01-11  18356500.0  1325400.0   21517300.0
# 2017-01-12  18653900.0  1349500.0   20968200.0
# 2017-01-13  24884300.0  1290200.0   19422300.0
# 2017-01-17  15294500.0  1439700.0   20620400.0
# 2017-01-18  13145900.0  1027700.0   19670100.0
# 2017-01-19  12195500.0  1070500.0   18451700.0
# 2017-01-20  19097200.0  1306200.0   30213500.0
# 2017-01-23  16593600.0  2457400.0   23097600.0
# 2017-01-24  15162700.0  1688400.0   24672900.0
# 2017-01-25  18731300.0  1655400.0   23672700.0
# 2017-01-26  20020100.0  3493300.0   43554600.0
# 2017-01-27  19539500.0  3752500.0   44818000.0
# 2017-01-30  18956100.0  3516900.0   31651400.0
# ...

# %%
style.use('ggplot')

start = dt.datetime(2017,1,1)
end = dt.datetime(2018, 12, 30)

df = web.DataReader(['MSFT','GOOGL', 'FB'], 'yahoo', start, end)

df
df.describe()
# Out:
# Attributes        High                                  Low               \
# Symbols             FB        GOOGL        MSFT          FB        GOOGL
# count       501.000000   501.000000  501.000000  501.000000   501.000000
# mean        165.647206  1040.044688   87.214890  162.389701  1021.258025
# std          20.149767   119.171504   16.666189   19.938725   114.558152
# min         117.839996   811.440002   62.660000  115.510002   796.890015
# 25%         150.210007   952.799988   71.709999  147.440002   940.059998
# 50%         169.070007  1051.699951   86.510002  165.820007  1028.520020
# 75%         180.130005  1121.800049  101.949997  177.179993  1103.979980
# max         218.619995  1291.439941  116.180000  214.270004  1263.000000
#
# Attributes                    Open                                Close  \
# Symbols           MSFT          FB        GOOGL        MSFT          FB
# count       501.000000  501.000000   501.000000  501.000000  501.000000
# ...

# %%
df['Volume'].tail()
# Out:
# Symbols             FB      GOOGL         MSFT
# Date
# 2018-12-21  56901500.0  5232800.0  111242100.0
# 2018-12-24  22066000.0  1818000.0   43935200.0
# 2018-12-26  39723400.0  2315900.0   51634800.0
# 2018-12-27  31202500.0  2299800.0   49498500.0
# 2018-12-28  22627600.0  1719900.0   38196300.0

# %%
df['Close'].rolling(window=100).mean()
# Out:
# Symbols             FB        GOOGL      MSFT
# Date
# 2017-01-03         NaN          NaN       NaN
# 2017-01-04         NaN          NaN       NaN
# 2017-01-05         NaN          NaN       NaN
# 2017-01-06         NaN          NaN       NaN
# 2017-01-09         NaN          NaN       NaN
# 2017-01-10         NaN          NaN       NaN
# 2017-01-11         NaN          NaN       NaN
# 2017-01-12         NaN          NaN       NaN
# 2017-01-13         NaN          NaN       NaN
# 2017-01-17         NaN          NaN       NaN
# 2017-01-18         NaN          NaN       NaN
# 2017-01-19         NaN          NaN       NaN
# 2017-01-20         NaN          NaN       NaN
# 2017-01-23         NaN          NaN       NaN
# 2017-01-24         NaN          NaN       NaN
# 2017-01-25         NaN          NaN       NaN
# 2017-01-26         NaN          NaN       NaN
# 2017-01-27         NaN          NaN       NaN
# 2017-01-30         NaN          NaN       NaN
# ...

# %%
df['100ma'] = df['Close'].rolling(window=100).mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '100ma'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df['100 ma'] = df['Adj Close'].rolling(window=100).mean()
df.dropna(inplace= True)

# %%
df = web.DataReader(['FB'], 'yahoo', start, end)

# %%
df['100 ma'] = df['Adj Close'].rolling(window=100).mean()

# %%
df.dropna(inplace=True)

# %%
df

# %%
graph = df['100 ma'].plot()
plt.show()

# %%
dfMSFT = web.DataReader('MSFT', 'yahoo', start, end)
dfGOOGL = web.DataReader('GOOGL', 'yahoo', start, end)
dfFB = web.DataReader('FB', 'yahoo', start, end)

dfMSFT['100 ma MSFT'] = dfMSFT['Close'].rolling(window = 100).mean()
dfGOOGL['100 ma GOOGL'] = dfGOOGL['Close'].rolling(window = 100).mean()
dfFB['100 ma FB'] = dfFB['Close'].rolling(window = 100).mean()

graphMSFT = dfMSFT['100 ma MSFT'].plot()
graphGOOGL = dfGOOGL['100 ma GOOGL'].plot()
graphFB = dfFB['100 ma FB'].plot()

plt.legend(['MSFT', 'GOOGL', 'FB'])
plt.show()

# %%
tickers = ['MSFT', 'GOOGL', 'FB']

dailyClose = df['Adj Close'].reset_index().pivot('Date', 'Ticker', 'Adj Close')

daily_pct_change = dailyClose.pct_change()

daily_pct_change.hist(bins=50, sharex=True, figsize=(12,8))

plt.show
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ticker'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-57ac65d240b2> in <module>
#       1 tickers = ['MSFT', 'GOOGL', 'FB']
# ...

# %%
print(df)
# Out:
# Attributes        High                                  Low               \
# Symbols             FB        GOOGL        MSFT          FB        GOOGL
# Date
# 2017-01-03  117.839996   811.440002   62.840000  115.510002   796.890015
# 2017-01-04  119.660004   813.429993   62.750000  117.290001   804.109985
# 2017-01-05  120.949997   813.739990   62.660000  118.320000   805.919983
# 2017-01-06  123.879997   828.960022   63.150002  120.029999   811.500000
# 2017-01-09  125.430000   830.429993   63.080002  123.040001   821.619995
# 2017-01-10  125.500000   829.409973   63.070000  124.279999   823.140015
# 2017-01-11  126.120003   829.900024   63.230000  124.059998   821.469971
# 2017-01-12  126.730003   830.380005   63.400002  124.800003   821.010010
# 2017-01-13  129.270004   834.650024   62.869999  127.370003   829.520020
# 2017-01-17  128.339996   830.179993   62.700001  127.400002   823.200012
# 2017-01-18  128.429993   829.809998   62.700001  126.839996   824.080017
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-f2baaa40de00> in <module>
# ----> 1 df.sort_values(by='High')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4717
#    4718             by = by[0]
# -> 4719             k = self._get_label_or_level_values(by, axis=axis)
#    4720
#    4721             if isinstance(ascending, (tuple, list)):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1723                              .format(key=key,
#    1724                                      label_axis_name=label_axis_name,
# -> 1725                                      multi_message=multi_message))
#    1726
#    1727         return values
#
# ValueError: The column label 'High' is not unique.
# ...

# %%
df = web.DataReader('MSFT', 'yahoo', start, end)

# %%
df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2017-01-03   62.840000   62.130001   62.790001   62.580002   20694100.0
# 2017-01-04   62.750000   62.119999   62.480000   62.299999   21340000.0
# 2017-01-05   62.660000   62.029999   62.189999   62.299999   24876000.0
# 2017-01-06   63.150002   62.040001   62.299999   62.840000   19922900.0
# 2017-01-09   63.080002   62.540001   62.759998   62.639999   20256600.0
# 2017-01-10   63.070000   62.279999   62.730000   62.619999   18593000.0
# 2017-01-11   63.230000   62.430000   62.610001   63.189999   21517300.0
# 2017-01-12   63.400002   61.950001   63.060001   62.610001   20968200.0
# 2017-01-13   62.869999   62.349998   62.619999   62.700001   19422300.0
# 2017-01-17   62.700001   62.029999   62.680000   62.529999   20620400.0
# 2017-01-18   62.700001   62.119999   62.669998   62.500000   19670100.0
# 2017-01-19   62.980000   62.200001   62.240002   62.299999   18451700.0
# ...

# %%
df.reset_index()
# Out:
#           Date        High         Low        Open       Close       Volume  \
# 0   2017-01-03   62.840000   62.130001   62.790001   62.580002   20694100.0
# 1   2017-01-04   62.750000   62.119999   62.480000   62.299999   21340000.0
# 2   2017-01-05   62.660000   62.029999   62.189999   62.299999   24876000.0
# 3   2017-01-06   63.150002   62.040001   62.299999   62.840000   19922900.0
# 4   2017-01-09   63.080002   62.540001   62.759998   62.639999   20256600.0
# 5   2017-01-10   63.070000   62.279999   62.730000   62.619999   18593000.0
# 6   2017-01-11   63.230000   62.430000   62.610001   63.189999   21517300.0
# 7   2017-01-12   63.400002   61.950001   63.060001   62.610001   20968200.0
# 8   2017-01-13   62.869999   62.349998   62.619999   62.700001   19422300.0
# 9   2017-01-17   62.700001   62.029999   62.680000   62.529999   20620400.0
# 10  2017-01-18   62.700001   62.119999   62.669998   62.500000   19670100.0
# ...

# %%
prices = df['Close'].tolist()

# %%
prices
# Out:
# [62.58000183105469,
#  62.29999923706055,
#  62.29999923706055,
#  62.84000015258789,
#  62.63999938964844,
#  62.619998931884766,
#  63.189998626708984,
#  62.61000061035156,
#  62.70000076293945,
#  62.529998779296875,
#  62.5,
#  62.29999923706055,
#  62.7400016784668,
#  62.959999084472656,
#  63.52000045776367,
#  63.68000030517578,
#  64.2699966430664,
#  65.77999877929688,
#  65.12999725341797,
#  64.6500015258789,
#  63.58000183105469,
#  63.16999816894531,
#  63.68000030517578,
#  63.63999938964844,
#  63.43000030517578,
#  63.34000015258789,
#  64.05999755859375,
#  64.0,
#  64.72000122070312,
#  64.56999969482422,
#  64.52999877929688,
#  64.5199966430664,
#  64.62000274658203,
#  64.48999786376953,
#  64.36000061035156,
#  64.62000274658203,
#  64.62000274658203,
#  64.2300033569336,
#  63.97999954223633,
#  64.94000244140625,
#  64.01000213623047,
#  64.25,
#  64.2699966430664,
#  64.4000015258789,
#  64.98999786376953,
#  64.7300033569336,
#  64.93000030517578,
# ...

# %%
prices = np.reshape(prices, (len(prices), 1))

# %%
prices
# Out:
# array([[ 62.58000183],
#        [ 62.29999924],
#        [ 62.29999924],
#        [ 62.84000015],
#        [ 62.63999939],
#        [ 62.61999893],
#        [ 63.18999863],
#        [ 62.61000061],
#        [ 62.70000076],
#        [ 62.52999878],
#        [ 62.5       ],
#        [ 62.29999924],
#        [ 62.74000168],
#        [ 62.95999908],
#        [ 63.52000046],
#        [ 63.68000031],
#        [ 64.26999664],
#        [ 65.77999878],
#        [ 65.12999725],
#        [ 64.65000153],
#        [ 63.58000183],
#        [ 63.16999817],
#        [ 63.68000031],
#        [ 63.63999939],
#        [ 63.43000031],
#        [ 63.34000015],
#        [ 64.05999756],
#        [ 64.        ],
#        [ 64.72000122],
#        [ 64.56999969],
#        [ 64.52999878],
#        [ 64.51999664],
#        [ 64.62000275],
#        [ 64.48999786],
#        [ 64.36000061],
#        [ 64.62000275],
#        [ 64.62000275],
#        [ 64.23000336],
#        [ 63.97999954],
#        [ 64.94000244],
# ...

# %%
df['Close']
# Out:
# Date
# 2017-01-03     62.580002
# 2017-01-04     62.299999
# 2017-01-05     62.299999
# 2017-01-06     62.840000
# 2017-01-09     62.639999
# 2017-01-10     62.619999
# 2017-01-11     63.189999
# 2017-01-12     62.610001
# 2017-01-13     62.700001
# 2017-01-17     62.529999
# 2017-01-18     62.500000
# 2017-01-19     62.299999
# 2017-01-20     62.740002
# 2017-01-23     62.959999
# 2017-01-24     63.520000
# 2017-01-25     63.680000
# 2017-01-26     64.269997
# 2017-01-27     65.779999
# 2017-01-30     65.129997
# 2017-01-31     64.650002
# 2017-02-01     63.580002
# 2017-02-02     63.169998
# 2017-02-03     63.680000
# 2017-02-06     63.639999
# 2017-02-07     63.430000
# 2017-02-08     63.340000
# 2017-02-09     64.059998
# 2017-02-10     64.000000
# 2017-02-13     64.720001
# 2017-02-14     64.570000
#                  ...
# 2018-11-14    104.970001
# 2018-11-15    107.279999
# 2018-11-16    108.290001
# 2018-11-19    104.620003
# 2018-11-20    101.709999
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2017-01-03', '2017-01-04', '2017-01-05', '2017-01-06',
#                '2017-01-09', '2017-01-10', '2017-01-11', '2017-01-12',
#                '2017-01-13', '2017-01-17',
#                ...
#                '2018-12-14', '2018-12-17', '2018-12-18', '2018-12-19',
#                '2018-12-20', '2018-12-21', '2018-12-24', '2018-12-26',
#                '2018-12-27', '2018-12-28'],
#               dtype='datetime64[ns]', name='Date', length=501, freq=None)

# %%
dates = df.index.tolist()

# %%
dates = np.reshape(dates, (len(dates), 1))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
regressor = LinearRegression()
regressor.fit(dates, prices)

plt.scatter(dates, prices, color = 'yellow', label ='Actual Price')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-788f5e67fe6c> in <module>
#       1 regressor = LinearRegression()
# ----> 2 regressor.fit(dates, prices)
#       3
#       4 plt.scatter(dates, prices, color = 'yellow', label ='Actual Price')
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...

# %%
dates = np.reshape(dates, (len(dates), 1))
prices = np.reshape(prices, (len(prices), 1))

# %%
regressor = LinearRegression()
regressor.fit(dates, prices)
 
#Visualize Results
plt.scatter(dates, prices, color='yellow', label= 'Actual Price') #plotting the initial datapoints
plt.plot(dates, regressor.predict(dates), color='red', linewidth=3, label = 'Predicted Price') #plotting the line made by linear regression
plt.title('Linear Regression | Time vs. Price')
plt.legend()
plt.xlabel('Date Integer')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-8ab1cbe87a60> in <module>
#       1 regressor = LinearRegression()
# ----> 2 regressor.fit(dates, prices)
#       3
#       4 #Visualize Results
#       5 plt.scatter(dates, prices, color='yellow', label= 'Actual Price') #plotting the initial datapoints
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...

# %%
x = df.iloc[:,:-1].values
print(x)
# Out:
# 62.58000183105469

# %%
close_x = df['Close']

# %%
test= close_x[-20:]
test
# Out:
# Date
# 2018-11-29    110.190002
# 2018-11-30    110.889999
# 2018-12-03    112.089996
# 2018-12-04    108.519997
# 2018-12-06    109.190002
# 2018-12-07    104.820000
# 2018-12-10    107.589996
# 2018-12-11    108.589996
# 2018-12-12    109.080002
# 2018-12-13    109.449997
# 2018-12-14    106.029999
# 2018-12-17    102.889999
# 2018-12-18    103.970001
# 2018-12-19    103.690002
# 2018-12-20    101.510002
# 2018-12-21     98.230003
# 2018-12-24     94.129997
# 2018-12-26    100.559998
# 2018-12-27    101.180000
# 2018-12-28    100.389999
# Name: Close, dtype: float64

# %%
train= close_x[:-20]
train
# Out:
# Date
# 2017-01-03     62.580002
# 2017-01-04     62.299999
# 2017-01-05     62.299999
# 2017-01-06     62.840000
# 2017-01-09     62.639999
# 2017-01-10     62.619999
# 2017-01-11     63.189999
# 2017-01-12     62.610001
# 2017-01-13     62.700001
# 2017-01-17     62.529999
# 2017-01-18     62.500000
# 2017-01-19     62.299999
# 2017-01-20     62.740002
# 2017-01-23     62.959999
# 2017-01-24     63.520000
# 2017-01-25     63.680000
# 2017-01-26     64.269997
# 2017-01-27     65.779999
# 2017-01-30     65.129997
# 2017-01-31     64.650002
# 2017-02-01     63.580002
# 2017-02-02     63.169998
# 2017-02-03     63.680000
# 2017-02-06     63.639999
# 2017-02-07     63.430000
# 2017-02-08     63.340000
# 2017-02-09     64.059998
# 2017-02-10     64.000000
# 2017-02-13     64.720001
# 2017-02-14     64.570000
#                  ...
# 2018-10-17    110.709999
# 2018-10-18    108.500000
# 2018-10-19    108.660004
# 2018-10-22    109.629997
# 2018-10-23    108.099998
# ...

# %%
close_x.target[-20:]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-34f826ae7afe> in <module>
# ----> 1 close_x.target[-20:]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'target'

# %%
import seaborn as sns
sns.pairplot(df)

# %%
sns.distplot(df['Close'])

# %%
df.corr()
# Out:
#                High       Low      Open     Close    Volume  Adj Close
# High       1.000000  0.998181  0.999133  0.998632  0.329407   0.998750
# Low        0.998181  1.000000  0.998410  0.998952  0.287354   0.998764
# Open       0.999133  0.998410  1.000000  0.997444  0.316761   0.997497
# Close      0.998632  0.998952  0.997444  1.000000  0.303154   0.999901
# Volume     0.329407  0.287354  0.316761  0.303154  1.000000   0.305946
# Adj Close  0.998750  0.998764  0.997497  0.999901  0.305946   1.000000

# %%
Y = df['Close'].tolist()
X = df['Adj Close'].tolist()

Y = np.reshape(Y, (len(Y), 1))
X = np.reshape(X, (len(X), 1))

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.4, random_state=101)

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([[ 64.84191216],
#        [100.99644871],
#        [ 71.75536545],
#        [ 62.54016428],
#        [ 73.89015828],
#        [ 98.38359648],
#        [ 64.7326124 ],
#        [ 78.57291443],
#        [ 69.18732922],
#        [108.40314685],
#        [109.86088957],
#        [102.41967339],
#        [ 67.94856171],
#        [100.74850958],
#        [ 65.76492357],
#        [ 65.03022186],
#        [101.77839359],
#        [ 84.17031029],
#        [ 92.8233484 ],
#        [114.19457595],
#        [ 62.63261016],
#        [ 83.66943774],
#        [ 94.07666417],
#        [ 85.74851994],
#        [ 86.71245431],
#        [101.88328836],
#        [107.02467924],
#        [ 93.48798644],
#        [ 65.60681532],
#        [ 93.95322865],
#        [ 64.39820874],
#        [ 88.13001438],
#        [ 82.8661456 ],
#        [ 78.78920097],
#        [ 75.57332901],
#        [ 90.85793412],
#        [ 64.63961404],
#        [109.5805686 ],
#        [109.52313429],
#        [ 83.89625059],
# ...

# %%
plt.scatter(y_test, predictions)

# %%
plt.scatter(df.index, predictions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-ac34f8797dfd> in <module>
# ----> 1 plt.scatter(df.index, predictions)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2860         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2861         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2862         is not None else {}), **kwargs)
#    2863     sci(__ret)
#    2864     return __ret
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
# ...

# %%
len(df.index)
# Out:
# 501

# %%
len(predictions)
# Out:
# 201

# %%
df.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
missingVals = ["."]
gov = pd.read_csv('worldgovernance.csv', na_values = missingVals)

# %%
gov.reset_index()
# Out:
#     index             Country Currency  Law   Antidir  EffJud  LawRule  \
# 0       0           Argentina      ARG   0.0      4.0    6.00     5.35
# 1       1           Australia      AUS   1.0      4.0   10.00    10.00
# 2       2             Austria      AUT   0.0      2.0    9.50    10.00
# 3       3             Belgium      BEL   0.0      0.0    9.50    10.00
# 4       4              Brazil      BRA   0.0      3.0    5.75     6.32
# 5       5         Switzerland      CHE   0.0      2.0   10.00    10.00
# 6       6      Czech Republic      CZE   0.0      2.0     NaN      NaN
# 7       7             Germany      DEU   0.0      1.0    9.00     9.23
# 8       8             Denmark      DNK   0.0      2.0   10.00    10.00
# 9       9               Spain      ESP   0.0      4.0    6.25     7.80
# 10     10             Finland      FIN   0.0      3.0   10.00    10.00
# 11     11              France      FRA   0.0      3.0    8.00     8.98
# ...

# %%
gov.columns
# Out:
# Index(['Country', 'Currency', 'Law ', 'Antidir', 'EffJud', 'LawRule',
#        'Corruption', 'Expropriation', 'Repudiation', 'CIFAR', 'GAAPDiff',
#        'Absence', 'Divergence', 'DisclReq', 'LiabStd', 'Criminal', 'PubEnf',
#        'Sue ', 'Sanction', 'CompLaw', 'Newspaper', 'Crime', 'LabPower',
#        'TaxComp', 'TaxCheating', 'PropRights', 'Nenfor'],
#       dtype='object')

# %%
govData = gov[['Country','Crime', 'TaxCheating', 'TaxComp']]

# %%
govData
# Out:
#                Country  Crime  TaxCheating  TaxComp
# 0            Argentina    8.2         1.97     2.41
# 1            Australia   57.5         2.16     4.58
# 2              Austria   57.3         1.97     3.60
# 3              Belgium    NaN          NaN      NaN
# 4               Brazil    NaN         3.11     2.14
# 5          Switzerland   38.3         2.50     4.49
# 6       Czech Republic  177.2          NaN     2.54
# 7              Germany   74.1         2.94     3.41
# 8              Denmark   46.1         2.48     3.70
# 9                Spain  169.6         2.57     1.91
# 10             Finland   47.1         2.63     3.53
# 11              France  126.8         3.28     3.86
# 12      United Kingdom   96.4         2.65     4.67
# 13              Greece    NaN          NaN      NaN
# 14           Hong Kong  190.8          NaN     4.56
# 15             Hungary    NaN          NaN      NaN
# 16               India    NaN          NaN      NaN
# ...

# %%
govData.isnull()
# Out:
#     Country  Crime  TaxCheating  TaxComp
# 0     False  False        False    False
# 1     False  False        False    False
# 2     False  False        False    False
# 3     False   True         True     True
# 4     False   True        False    False
# 5     False  False        False    False
# 6     False  False         True    False
# 7     False  False        False    False
# 8     False  False        False    False
# 9     False  False        False    False
# 10    False  False        False    False
# 11    False  False        False    False
# 12    False  False        False    False
# 13    False   True         True     True
# 14    False  False         True    False
# 15    False   True         True     True
# 16    False   True         True     True
# 17    False   True         True     True
# 18    False  False        False    False
# 19    False  False        False    False
# 20    False   True         True     True
# 21    False  False        False    False
# ...

# %%
govData.dropna()
# Out:
#            Country  Crime  TaxCheating  TaxComp
# 0        Argentina    8.2         1.97     2.41
# 1        Australia   57.5         2.16     4.58
# 2          Austria   57.3         1.97     3.60
# 5      Switzerland   38.3         2.50     4.49
# 7          Germany   74.1         2.94     3.41
# 8          Denmark   46.1         2.48     3.70
# 9            Spain  169.6         2.57     1.91
# 10         Finland   47.1         2.63     3.53
# 11          France  126.8         3.28     3.86
# 12  United Kingdom   96.4         2.65     4.67
# 18           Italy   61.7         2.28     1.77
# 19           Japan    2.7         1.49     4.41
# 21          Mexico  100.8         3.35     2.46
# 23     Netherlands  122.8         3.08     3.40
# 24          Norway   26.9         3.10     3.96
# 26          Poland   99.6         2.61     2.19
# 27        Portugal   12.4         3.82     2.18
# 30          Sweden   80.1         2.30     3.39
# 32          Taiwan   34.0         1.98     3.25
# ...

# %%
ax = plt.gca()
govData.plot(kind='bar', x='Country', y='TaxComp', ax=ax)
govData.plot(kind='bar', x='Country', y='TaxCheating', color='orange', ax=ax)
govData.plot(kind='bar', x='Country', y='Crime', color='green', ax=ax)

plt.show()

# %%
govData
# Out:
#                Country  Crime  TaxCheating  TaxComp
# 0            Argentina    8.2         1.97     2.41
# 1            Australia   57.5         2.16     4.58
# 2              Austria   57.3         1.97     3.60
# 3              Belgium    NaN          NaN      NaN
# 4               Brazil    NaN         3.11     2.14
# 5          Switzerland   38.3         2.50     4.49
# 6       Czech Republic  177.2          NaN     2.54
# 7              Germany   74.1         2.94     3.41
# 8              Denmark   46.1         2.48     3.70
# 9                Spain  169.6         2.57     1.91
# 10             Finland   47.1         2.63     3.53
# 11              France  126.8         3.28     3.86
# 12      United Kingdom   96.4         2.65     4.67
# 13              Greece    NaN          NaN      NaN
# 14           Hong Kong  190.8          NaN     4.56
# 15             Hungary    NaN          NaN      NaN
# 16               India    NaN          NaN      NaN
# ...

# %%
govData.dropna()
govData.sort_values(by=['Crime'])
# Out:
#                Country  Crime  TaxCheating  TaxComp
# 19               Japan    2.7         1.49     4.41
# 0            Argentina    8.2         1.97     2.41
# 27            Portugal   12.4         3.82     2.18
# 24              Norway   26.9         3.10     3.96
# 32              Taiwan   34.0         1.98     3.25
# 22            Malaysia   34.5          NaN     4.34
# 5          Switzerland   38.3         2.50     4.49
# 29           Singapore   45.2          NaN     5.05
# 8              Denmark   46.1         2.48     3.70
# 10             Finland   47.1         2.63     3.53
# 25         New Zealand   52.3          NaN     5.00
# 2              Austria   57.3         1.97     3.60
# 1            Australia   57.5         2.16     4.58
# 18               Italy   61.7         2.28     1.77
# 31            Thailand   70.4          NaN     3.41
# 7              Germany   74.1         2.94     3.41
# 30              Sweden   80.1         2.30     3.39
# ...

# %%
govData.columns
govData = govData.dropna()
govData
# Out:
#            Country  Crime  TaxCheating  TaxComp
# 0        Argentina    8.2         1.97     2.41
# 1        Australia   57.5         2.16     4.58
# 2          Austria   57.3         1.97     3.60
# 5      Switzerland   38.3         2.50     4.49
# 7          Germany   74.1         2.94     3.41
# 8          Denmark   46.1         2.48     3.70
# 9            Spain  169.6         2.57     1.91
# 10         Finland   47.1         2.63     3.53
# 11          France  126.8         3.28     3.86
# 12  United Kingdom   96.4         2.65     4.67
# 18           Italy   61.7         2.28     1.77
# 19           Japan    2.7         1.49     4.41
# 21          Mexico  100.8         3.35     2.46
# 23     Netherlands  122.8         3.08     3.40
# 24          Norway   26.9         3.10     3.96
# 26          Poland   99.6         2.61     2.19
# 27        Portugal   12.4         3.82     2.18
# 30          Sweden   80.1         2.30     3.39
# 32          Taiwan   34.0         1.98     3.25
# ...

# %%
X = govData[['TaxCheating','TaxComp']]
Y = govData[['Crime']]

Y
# Out:
#     Crime
# 0     8.2
# 1    57.5
# 2    57.3
# 5    38.3
# 7    74.1
# 8    46.1
# 9   169.6
# 10   47.1
# 11  126.8
# 12   96.4
# 18   61.7
# 19    2.7
# 21  100.8
# 23  122.8
# 24   26.9
# 26   99.6
# 27   12.4
# 30   80.1
# 32   34.0
# 33  225.2

# %%
xtrain, xtest, ytest, ytrain = train_test_split(X, Y, test_size=0.3, random_state=101)
regression = LinearRegression()
regression.fit(xtrain, ytrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-6959783ce967> in <module>
#       1 xtrain, xtest, ytest, ytrain = train_test_split(X, Y, test_size=0.3, random_state=101)
#       2 regression = LinearRegression()
# ----> 3 regression.fit(xtrain, ytrain)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...
